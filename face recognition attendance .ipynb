# %% [markdown]
# - Create folder name **_processed** in directory to extract image from video and excute function **video_to_frames**
#
# - Create folder name **face detect** in directory to extract face from image and excute function **face_detect**
#
# - Run function **check_image** and pass 1 image path to check

# %% [markdown]
# # Extract image from video

# %%
import cv2
import time
import os

def video_to_frames(input_loc, output_loc, name_input):
    print(input_loc)
    # Log the time
    time_start = time.time()
    # Start capturing the feed
    cap = cv2.VideoCapture(input_loc)
   
    # Find the number of frames
    fps = cap.get(cv2.CAP_PROP_FPS)
    print("Frames per second", fps )
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) 
    print ("Number of frames: ", video_length)
    
    count = 0
    pic_count = 0
    skip_frame = 15
    print ("Converting video..\n")
    
    # process path
    name_file = name_input.split(".")[0]
    output_path = output_loc + "/" + name_file
    os.mkdir(output_path)

    # Start converting the video
    while cap.isOpened():
        # Extract the frame
        ret, frame = cap.read()
        if not ret:
            continue
        # Write the results back to output location.
        if (count % skip_frame == 0 ):
          cv2.imwrite((output_path + "/" + f"img{str(pic_count)}" + ".jpg"), frame)
          pic_count +=1
        count = count + 1
        # If there are no more frames left
        if (count > (video_length-1)):
            # Log the time again
            time_end = time.time()
            # Release the feed
            cap.release()
            # Print stats
            print ("Done extracting frames.\n%d frames extracted" % pic_count)
            print ("It took %d seconds forconversion." % (time_end-time_start))
            break

# %%
input_path = "/content/drive/MyDrive/Attendance Project/Video"
output_path = "/content/drive/MyDrive/Attendance Project/_processed"

# %%
files = [f for f in os.listdir(input_path)]
for f in files:
  video_to_frames( (input_path + "/" + f) , output_path, f)
# Out:
# /content/drive/MyDrive/Attendance Project/Video/Tuấn.mp4
# Frames per second 30.01523161007078
# Number of frames:  536
# Converting video..
#
# Done extracting frames.
# 36 frames extracted
# It took 4 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Trường.mp4
# Frames per second 30.01399203010099
# Number of frames:  414
# Converting video..
#
# Done extracting frames.
# 28 frames extracted
# It took 4 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Linh.mp4
# Frames per second 29.895282062830763
# Number of frames:  354
# Converting video..
#
# Done extracting frames.
# 24 frames extracted
# It took 4 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Hiếu.mp4
# Frames per second 28.052263135282672
# Number of frames:  518
# Converting video..
#
# Done extracting frames.
# 35 frames extracted
# It took 5 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Quân.mp4
# Frames per second 29.905097407704076
# Number of frames:  957
# Converting video..
#
# Done extracting frames.
# 64 frames extracted
# It took 9 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Xuân Anh.mp4
# Frames per second 29.998750052081164
# Number of frames:  864
# Converting video..
#
# Done extracting frames.
# 58 frames extracted
# It took 9 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Tân.mp4
# Frames per second 29.99981538575147
# Number of frames:  325
# Converting video..
#
# Done extracting frames.
# 22 frames extracted
# It took 3 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Đức.mp4
# Frames per second 29.893757377959865
# Number of frames:  574
# Converting video..
#
# Done extracting frames.
# 39 frames extracted
# It took 5 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Kiên.mp4
# Frames per second 29.832443076632824
# Number of frames:  506
# Converting video..
#
# Done extracting frames.
# 34 frames extracted
# It took 5 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Việt Đức.mp4
# Frames per second 29.734585864109526
# Number of frames:  609
# Converting video..
#
# Done extracting frames.
# 41 frames extracted
# It took 6 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Hùng.mp4
# Frames per second 29.90928341311889
# Number of frames:  726
# Converting video..
#
# Done extracting frames.
# 49 frames extracted
# It took 7 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Thắng.mp4
# Frames per second 30.00363949473161
# Number of frames:  338
# Converting video..
#
# Done extracting frames.
# 23 frames extracted
# It took 3 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/Vân.mp4
# Frames per second 29.867814738824794
# Number of frames:  444
# Converting video..
#
# Done extracting frames.
# 30 frames extracted
# It took 4 seconds forconversion.
# /content/drive/MyDrive/Attendance Project/Video/HĐức.mp4
# Frames per second 18.297088417161106
# Number of frames:  195
# Converting video..
#
# Done extracting frames.
# 13 frames extracted
# It took 2 seconds forconversion.

# %% [markdown]
# # Face Detection using retinaface

# %%
# !pip install retina-face
from retinaface import RetinaFace
# Out:
# Collecting retina-face
#   Downloading retina_face-0.0.5-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from retina-face) (1.19.5)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from retina-face) (2.7.0)
# Collecting gdown>=3.10.1
#   Downloading gdown-4.2.0.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: opencv-python>=3.4.4 in /usr/local/lib/python3.7/dist-packages (from retina-face) (4.5.4.58)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from retina-face) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->retina-face) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->retina-face) (4.62.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->retina-face) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->retina-face) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown>=3.10.1->retina-face) (3.3.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (1.13.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (1.6.3)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (0.4.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (3.10.0.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (12.0.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (0.37.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (2.7.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (3.1.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (2.7.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (0.12.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (1.41.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.9.0->retina-face) (0.21.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=1.9.0->retina-face) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.9.0->retina-face) (3.6.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=52bafb91370772be884528961625ff94c7fb5c1283c00f74015ab81fc8415d7a
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# Installing collected packages: gdown, retina-face
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# Successfully installed gdown-4.2.0 retina-face-0.0.5

# %%
def face_detect(input_path, output_path):
  # Get all folder name in directory need to be process
  folder_name = os.listdir(input_path)

  # Loop for each folder
  pic_count = 0
  for f in folder_name:

    # Create folder path
    folder_path = input_path + "/" + f
    output = output_path + "/" + f
    os.mkdir(output)
    # Get all image in folder
    images_name = [img for img in os.listdir(folder_path)]
    for image_name in images_name:
      # Loop each image
      file_path = folder_path + "/" + image_name

      faces = RetinaFace.extract_faces(img_path = file_path , align = True)
      for face in faces:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        
        cv2.imwrite((output + "/" + f"img{str(pic_count)}" + ".jpg"), face)
        pic_count +=1
    print(f"Done {f}")

# %%
input = "/content/drive/MyDrive/Attendance Project/_processed"
output = "/content/drive/MyDrive/Attendance Project/face detect"
face_detect(input,output)
# Out:
# Done Hiếu
# Done Tuấn
# Done Trường
# Done Linh
# Done Quân
# Done Xuân Anh
# Done Tân
# Done Đức
# Done Kiên
# Done Việt Đức
# Done Hùng
# Done Thắng
# Done Vân
# Done HĐức

# %% [markdown]
# # Using arcface extract embedding and calculate distance

# %%
label_name = os.listdir("/content/drive/MyDrive/Attendance Project/face detect")

# %%
len(label_name)
# Out:
# 14

# %%
label_name
# Out:
# ['Hiếu',
#  'Tuấn',
#  'Trường',
#  'Linh',
#  'Quân',
#  'Xuân Anh',
#  'Tân',
#  'Đức',
#  'Kiên',
#  'Việt Đức',
#  'Hùng',
#  'Thắng',
#  'Vân',
#  'HĐức']

# %%
pip install arcface
# Out:
# Requirement already satisfied: arcface in /usr/local/lib/python3.7/dist-packages (0.0.8)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.7/dist-packages (from arcface) (6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from arcface) (1.19.5)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.7/dist-packages (from arcface) (2.26.0)
# Requirement already satisfied: tensorflow>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from arcface) (2.7.0)
# Requirement already satisfied: opencv-python>=4.4 in /usr/local/lib/python3.7/dist-packages (from arcface) (4.5.4.58)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->arcface) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->arcface) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->arcface) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->arcface) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (0.37.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (3.10.0.2)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (3.17.3)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (2.7.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (1.13.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (12.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (0.21.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (1.41.1)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (0.2.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (0.12.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (1.1.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (2.7.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.3.0->arcface) (1.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.3.0->arcface) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.0->arcface) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.0->arcface) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.0->arcface) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.0->arcface) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.0->arcface) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.0->arcface) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow>=2.3.0->arcface) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=2.3.0->arcface) (3.6.0)

# %%
from arcface import ArcFace
face_rec = ArcFace.ArcFace()

# %%
def extract_file_name(input_path):
  list_name_file = {}
  # Get all folder name in directory need to be process
  folder_name = os.listdir(input_path)

  # Loop for each folder
  for f in folder_name:

    # Create folder path
    folder_path = input_path + "/" + f
    # Get all image in folder
    images_name = [img for img in os.listdir(folder_path)]
    list_file_path = []
    for image_name in images_name:
      # Loop each image
      file_path = folder_path + "/" + image_name
      # Get all path of image in folder
      list_file_path.append(file_path) 

    # Add all file path to dictionary
    list_name_file[f] = list_file_path
  return list_name_file

# %%
list_name_file = extract_file_name("/content/drive/MyDrive/Attendance Project/face detect")
list_name_file
# Out:
# {'Hiếu': ['/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img0.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img1.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img2.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img3.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img4.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img5.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img6.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img7.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img8.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img9.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img10.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img11.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img12.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img13.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img14.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img15.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img16.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img17.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img18.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img19.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img20.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img21.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img22.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img23.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img24.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img25.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img26.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img27.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img28.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img29.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img30.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img31.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img32.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img33.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hiếu/img34.jpg'],
#  'Hùng': ['/content/drive/MyDrive/Attendance Project/face detect/Hùng/img379.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img380.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img381.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img382.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img383.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img384.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img385.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img386.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img387.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img388.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img389.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img390.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img391.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img392.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img393.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img394.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img395.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img396.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img397.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img398.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img399.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img400.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img401.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img402.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img403.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img404.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img405.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img406.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img407.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img408.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img409.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img410.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img411.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img412.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img413.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img414.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img415.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img416.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img417.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img418.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img419.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img420.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img421.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img422.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/img423.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Hùng/
jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img451.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img452.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img453.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img454.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img455.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img456.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img457.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img458.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img459.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img460.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img461.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img462.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img463.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img464.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img465.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img466.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img467.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img468.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img469.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img470.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img471.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img472.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img473.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img474.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img475.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img476.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img477.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img478.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Vân/img479.jpg'],
#  'Việt Đức': ['/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img338.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img339.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img340.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img341.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img342.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img343.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img344.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img345.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img346.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img347.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img348.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img349.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img350.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img351.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img352.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img353.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img354.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img355.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img356.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img357.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img358.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img359.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img360.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img361.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img362.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img363.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img364.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img365.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img366.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img367.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img368.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img369.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img370.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img371.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img372.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img373.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img374.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img375.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img376.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img377.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Việt Đức/img378.jpg'],
#  'Xuân Anh': ['/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img185.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img186.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img187.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img188.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img189.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img190.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img191.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img192.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img193.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img194.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img195.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img196.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img197.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img198.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img199.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img200.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img201.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img202.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img203.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img204.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img205.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img206.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img207.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img208.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img209.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img210.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img211.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img212.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img213.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img214.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img215.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img216.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img217.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img218.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img219.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img220.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img221.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img222.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img223.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img224.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img225.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img226.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img227.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img228.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img229.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img230.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img231.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img232.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img233.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img234.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img235.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img236.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img237.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img238.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img239.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img240.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img241.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Xuân Anh/img242.jpg'],
#  'Đức': ['/content/drive/MyDrive/Attendance Project/face detect/Đức/img265.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img266.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img267.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img268.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img269.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img270.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img271.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img272.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img273.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img274.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img275.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img276.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img277.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img278.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img279.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img280.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img281.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img282.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img283.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img284.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img285.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img286.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img287.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img288.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img289.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img290.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img291.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img292.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img293.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img294.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img295.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img296.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img297.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img298.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img299.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img300.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img301.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img302.jpg',
#   '/content/drive/MyDrive/Attendance Project/face detect/Đức/img303.jpg']}

# %%
def extract_embedding(input_dict):
  dict_emb = {}
  for i in input_dict.keys():
    dict_emb[i] = face_rec.calc_emb(list_name_file[i])
  return dict_emb

# %%
dict_emb = extract_embedding(list_name_file)

# %% [markdown]
# # Process input image to check

# %%
def check_image(input_loc_image):
  # Read and plot image
  img = cv2.imread(input_loc_image)
  scale_percent = 40 # percent of original size
  width = int(img.shape[1] * scale_percent / 100)
  height = int(img.shape[0] * scale_percent / 100)
  dim = (width, height)
  img_resized = cv2.resize(img, dim )
  cv2_imshow(img_resized)  

  # Detect face from input image
  faces = RetinaFace.extract_faces(img_path = input_loc_image , align = True)
  for face in faces:
    face_detect = cv2.cvtColor(faces[0], cv2.COLOR_BGR2RGB)   
    cv2.imwrite("image_test.jpg", face_detect)
    emb = face_rec.calc_emb("image_test.jpg")
    
    name = "unknow"
  # Compair input image with image in database
  for k,v in dict_emb.items():
    # for item in dict_emb[i]:
      for values in v:
        # Function return distance using l2 norm
        distance = face_rec.get_distance_embeddings(emb,values)
        # print(k, distance)
        if distance < 0.5:
          name = k
          return name
        else:
          name = "unknow"
  return name

# %%
check_image("/content/img10.jpg")
# Out:
# <PIL.Image.Image image mode=RGB size=512x288 at 0x7FA855CBEFD0>
# 'Tân'
